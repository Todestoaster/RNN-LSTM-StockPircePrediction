# %%
import os
import time
import csv
import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import save_model, load_model
from keras.callbacks import EarlyStopping
import plotly.express as px
import plotly.graph_objs as go
import joblib

# Erstelle den Ordner zum Speichern der Modelle, falls nicht bereits vorhanden
os.makedirs('./models', exist_ok=True)

# CSV-Datei für die Ergebnisse
csv_filename = './results/hyperparameter_search_results.csv'
os.makedirs('./results', exist_ok=True)

# %%
# Lade die historischen Daten einer Aktie (z.B. Apple)
symbol = "AAPL"  # Apple-Aktien
start_date = "2000-01-01"  # Startdatum für die Daten
end_date = "2024-10-10"    # Enddatum für die Daten

# Daten herunterladen von Yahoo Finance
df = yf.download(symbol, start=start_date, end=end_date)

# Überprüfen der Daten
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2000-01-03  0.936384  1.004464  0.907924  0.999442   0.844004  535796800
# 2000-01-04  0.966518  0.987723  0.903460  0.915179   0.772846  512377600
# 2000-01-05  0.926339  0.987165  0.919643  0.928571   0.784155  778321600
# 2000-01-06  0.947545  0.955357  0.848214  0.848214   0.716296  767972800
# 2000-01-07  0.861607  0.901786  0.852679  0.888393   0.750226  460734400

# %%
# Daten aus den relevanten Spalten entnehmen
features = df[['Open', 'High', 'Low', 'Adj Close', 'Volume']]
target = df['Close']

# MinMaxScaler initialisieren und die Features skalieren
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = scaler.fit_transform(features)
scaled_target = scaler.fit_transform(target.values.reshape(-1, 1))
joblib.dump(scaler, './scaler/scaler.pkl')
# Out:
# ['./scaler/scaler.pkl']

# %%
val_size= 0.2
# Definiere die möglichen Werte für die Hyperparameter
hyperparameters = {
    'windowsize': [1, 2, 5, 10, 15, 20, 30, 60],
    'batchsize': [1, 5, 14, 30, 64, 128, 256, 512],
    'epochs': [30],
    'units': [1, 2, 5, 6, 8, 12, 16, 32, 64, 128],
    'lstm_layers': [1, 2, 3]
}

# %%
# Prüfe, ob das Modell bereits existiert
def model_exists(window_size, batch_size, epochs, units, lstm_layers):
    if os.path.exists(csv_filename):
        with open(csv_filename, 'r') as file:
            reader = csv.reader(file)
            for row in reader:
                if row[1:6] == [str(window_size), str(batch_size), str(epochs), str(units), str(lstm_layers)]:
                    return True
    return False

# Schreibe oder appende die Ergebnisse in die CSV
def write_to_csv(model_name, window_size, batch_size, epochs, units, lstm_layers, mse, mae, r2):
    file_exists = os.path.isfile(csv_filename)
    with open(csv_filename, 'a', newline='') as file:
        writer = csv.writer(file)
        if not file_exists:
            # Header hinzufügen, wenn die Datei neu erstellt wird
            writer.writerow(['Model Name', 'Window Size', 'Batch Size', 'Epochs', 'Units', 'LSTM Layers', 'MSE', 'MAE', 'R2'])
        writer.writerow([model_name, window_size, batch_size, epochs, units, lstm_layers, mse, mae, r2])

def create_windowed_data(features, target, window_size=60):
    X, y = [], []
    for i in range(window_size, len(features)):
        X.append(features[i-window_size:i])
        y.append(target[i])
    return np.array(X), np.array(y)

# Zufällige Suche über die Hyperparameter
def random_search(n_iter=10):
    results = []

    for _ in range(n_iter):
        # Zufällige Auswahl von Hyperparametern
        window_size = np.random.choice(hyperparameters['windowsize'])
        batch_size = np.random.choice(hyperparameters['batchsize'])
        epochs = np.random.choice(hyperparameters['epochs'])
        units = int(np.random.choice(hyperparameters['units']))
        lstm_layers = np.random.choice(hyperparameters['lstm_layers'])

        print(f"Iteration: {_}, window_size={window_size}, batch_size={batch_size}, epochs={epochs}, units={units}, lstm_layers={lstm_layers}")

        # Prüfe, ob das Modell mit diesen Parametern bereits existiert
        if model_exists(window_size, batch_size, epochs, units, lstm_layers):
            print(f"Modell mit den Parametern (ws={window_size}, bs={batch_size}, ep={epochs}, units={units}, layers={lstm_layers}) existiert bereits. Überspringe...")
            continue

        # Daten vorbereiten mit aktuellem window_size
        X, y = create_windowed_data(scaled_features, scaled_target, window_size=window_size)
        X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=val_size, random_state=42)

        # Modell erstellen
        model = Sequential()

        # Ersten LSTM Layer hinzufügen
        model.add(LSTM(units=units, return_sequences=True if lstm_layers > 1 else False, input_shape=(X_train.shape[1], X_train.shape[2])))
        model.add(Dropout(0.2))

        # Weitere LSTM Layer falls vorhanden
        for layer in range(1, lstm_layers):
            model.add(LSTM(units=units, return_sequences=False if layer == lstm_layers - 1 else True))
            model.add(Dropout(0.2))

        # Dense-Schicht hinzufügen
        model.add(Dense(units=1))

        # Modell kompilieren
        model.compile(optimizer='adam', loss='mean_squared_error')
        earlystop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        # Modell trainieren
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=1, callbacks=[earlystop])

        # Vorhersagen auf den Validierungsdaten
        y_pred = model.predict(X_val)

        # Den Skalierungsfaktor rückgängig machen, um die echten Werte wiederherzustellen
        y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))
        y_pred_rescaled = scaler.inverse_transform(y_pred)

        # Berechne die Metriken
        mse = mean_squared_error(y_val_true, y_pred_rescaled)
        mae = mean_absolute_error(y_val_true, y_pred_rescaled)
        r2 = r2_score(y_val_true, y_pred_rescaled)

        # Ergebnisse ausgeben
        print(f"Validation MSE: {mse}, MAE: {mae}, R2: {r2}")

        # Modellname basierend auf einem Zeitstempel
        timestamp = time.strftime("%Y%m%d-%H%M%S")
        model_name = f"model_{timestamp}_ws{window_size}_bs{batch_size}_epochs{epochs}_units{units}_layers{lstm_layers}.keras"
        save_model(model, f'./models/{model_name}')

        # Ergebnis in die CSV-Datei schreiben
        write_to_csv(model_name, window_size, batch_size, epochs, units, lstm_layers, mse, mae, r2)

        # Ergebnis in die Resultsliste einfügen
        results.append((window_size, batch_size, epochs, units, lstm_layers, mse, mae, r2, model_name))

    # Ergebnisse sortieren nach dem besten MSE
    results = sorted(results, key=lambda x: x[5])  # Sortiere nach MSE
    best_params = results[0]

    print("\nBeste Hyperparameter-Kombination:")
    print(f"window_size={best_params[0]}, batch_size={best_params[1]}, epochs={best_params[2]}, units={best_params[3]}, lstm_layers={best_params[4]}")

    return results

# %%
# Beispielhafte Ausführung der Funktion
results = random_search(n_iter=100)
# Out:
# Iteration: 0, window_size=60, batch_size=64, epochs=30, units=16, lstm_layers=1
# Epoch 1/30
# 78/78 [==============================] - 1s 7ms/step - loss: 0.0222 - val_loss: 4.8722e-04
# Epoch 2/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 3.8690e-04
# Epoch 3/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 2.4507e-04
# Epoch 4/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 1.3083e-04
# Epoch 5/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 4.7741e-04
# Epoch 6/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 1.2598e-04
# Epoch 7/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 1.3632e-04
# Epoch 8/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 1.0303e-04
# Epoch 9/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 9.1971e-05
# Epoch 10/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 9.6882e-05
# Epoch 11/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 1.3436e-04
# Epoch 12/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 9.0967e-05
# Epoch 13/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 9.7091e-05
# Epoch 14/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 1.1172e-04
# Epoch 15/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 9.0889e-05
# Epoch 16/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 9.0599e-05
# Epoch 17/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 1.0320e-04
# Epoch 18/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 1.8393e-04
# Epoch 19/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 9.2985e-05
# Epoch 20/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 1.0690e-04
# Epoch 21/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 6.5491e-05
# Epoch 22/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 1.2819e-04
# Epoch 23/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 1.2658e-04
# Epoch 24/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 1.4320e-04
# Epoch 25/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 1.1058e-04
# Epoch 26/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 6.1043e-05
# Epoch 27/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 7.3394e-05
# Epoch 28/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 1.7889e-04
# Epoch 29/30
# 78/78 [==============================] - 0s 5ms/step - loss: 9.7319e-04 - val_loss: 7.1930e-05
# Epoch 30/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 1.0440e-04
# 39/39 [==============================] - 0s 1ms/step
# Validation MSE: 5.745197354513015, MAE: 1.986859016403978, R2: 0.9983117406766632
# Iteration: 1, window_size=15, batch_size=5, epochs=30, units=64, lstm_layers=3
# Epoch 1/30
# 995/995 [==============================] - 8s 6ms/step - loss: 0.0021 - val_loss: 2.0757e-04
# Epoch 2/30
# 995/995 [==============================] - 5s 5ms/step - loss: 0.0011 - val_loss: 1.5217e-04
# Epoch 3/30
# 995/995 [==============================] - 6s 6ms/step - loss: 9.4042e-04 - val_loss: 1.8663e-04
# Epoch 4/30
# 995/995 [==============================] - 6s 6ms/step - loss: 9.7659e-04 - val_loss: 7.0666e-04
# Epoch 5/30
# 995/995 [==============================] - 6s 6ms/step - loss: 9.3570e-04 - val_loss: 5.5460e-04
# Epoch 6/30
# 995/995 [==============================] - 6s 6ms/step - loss: 9.3431e-04 - val_loss: 2.2286e-04
# Epoch 7/30
# 995/995 [==============================] - 6s 6ms/step - loss: 8.2986e-04 - val_loss: 1.3241e-04
# Epoch 8/30
# 995/995 [==============================] - 5s 5ms/step - loss: 8.6438e-04 - val_loss: 1.8134e-04
# Epoch 9/30
# 995/995 [==============================] - 5s 5ms/step - loss: 7.9344e-04 - val_loss: 0.0011
# Epoch 10/30
# 995/995 [==============================] - 5s 5ms/step - loss: 7.0944e-04 - val_loss: 9.6988e-05
# Epoch 11/30
# 995/995 [==============================] - 5s 5ms/step - loss: 8.4342e-04 - val_loss: 1.6279e-04
# Epoch 12/30
# 995/995 [==============================] - 5s 5ms/step - loss: 7.3257e-04 - val_loss: 1.8141e-04
# Epoch 13/30
# 995/995 [==============================] - 5s 5ms/step - loss: 6.8654e-04 - val_loss: 1.8883e-04
# Epoch 14/30
# 995/995 [==============================] - 5s 5ms/step - loss: 6.9812e-04 - val_loss: 5.9835e-04
# Epoch 15/30
# 995/995 [==============================] - 5s 5ms/step - loss: 6.7866e-04 - val_loss: 8.1986e-05
# Epoch 16/30
# 995/995 [==============================] - 6s 6ms/step - loss: 6.5765e-04 - val_loss: 1.0792e-04
# Epoch 17/30
30
# 78/78 [==============================] - 0s 2ms/step - loss: 3.6063e-04 - val_loss: 4.7320e-05
# Epoch 29/30
# 78/78 [==============================] - 0s 2ms/step - loss: 3.4248e-04 - val_loss: 4.4942e-05
# Epoch 30/30
# 78/78 [==============================] - 0s 2ms/step - loss: 3.7032e-04 - val_loss: 9.1313e-05
# 39/39 [==============================] - 0s 539us/step
# Validation MSE: 5.0249972882070635, MAE: 1.2549381754972133, R2: 0.9984858842866106
# Iteration: 4, window_size=20, batch_size=1, epochs=30, units=1, lstm_layers=3
# Epoch 1/30
# 4969/4969 [==============================] - 18s 3ms/step - loss: 0.0191 - val_loss: 0.0042
# Epoch 2/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0136 - val_loss: 0.0031
# Epoch 3/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0145 - val_loss: 0.0041
# Epoch 4/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0143 - val_loss: 0.0040
# Epoch 5/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0147 - val_loss: 0.0028
# Epoch 6/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0138 - val_loss: 0.0035
# Epoch 7/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0143 - val_loss: 0.0044
# Epoch 8/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0137 - val_loss: 0.0037
# Epoch 9/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0151 - val_loss: 0.0047
# Epoch 10/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0140 - val_loss: 0.0039
# Epoch 11/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0142 - val_loss: 0.0029
# Epoch 12/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0131 - val_loss: 0.0044
# Epoch 13/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0138 - val_loss: 0.0040
# Epoch 14/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0135 - val_loss: 0.0028
# Epoch 15/30
# 4969/4969 [==============================] - 16s 3ms/step - loss: 0.0147 - val_loss: 0.0036
# 39/39 [==============================] - 0s 1ms/step
# Validation MSE: 155.39125000594322, MAE: 8.423470775530113, R2: 0.953641445923842
# Iteration: 5, window_size=30, batch_size=14, epochs=30, units=64, lstm_layers=3
# Epoch 1/30
# 355/355 [==============================] - 7s 14ms/step - loss: 0.0020 - val_loss: 1.9483e-04
# Epoch 2/30
# 355/355 [==============================] - 5s 13ms/step - loss: 0.0013 - val_loss: 3.6810e-04
# Epoch 3/30
# 355/355 [==============================] - 5s 13ms/step - loss: 9.5305e-04 - val_loss: 4.0816e-04
# Epoch 4/30
# 355/355 [==============================] - 5s 13ms/step - loss: 8.0907e-04 - val_loss: 3.8098e-04
# Epoch 5/30
# 355/355 [==============================] - 5s 13ms/step - loss: 9.0283e-04 - val_loss: 1.3153e-04
# Epoch 6/30
# 355/355 [==============================] - 5s 13ms/step - loss: 7.0202e-04 - val_loss: 1.5993e-04
# Epoch 7/30
# 355/355 [==============================] - 5s 13ms/step - loss: 7.6853e-04 - val_loss: 1.9625e-04
# Epoch 8/30
# 355/355 [==============================] - 5s 13ms/step - loss: 7.9100e-04 - val_loss: 3.2119e-04
# Epoch 9/30
# 355/355 [==============================] - 5s 13ms/step - loss: 7.5168e-04 - val_loss: 1.5747e-04
# Epoch 10/30
# 355/355 [==============================] - 5s 13ms/step - loss: 5.9285e-04 - val_loss: 1.1090e-04
# Epoch 11/30
# 355/355 [==============================] - 5s 13ms/step - loss: 6.1669e-04 - val_loss: 8.4024e-05
# Epoch 12/30
# 355/355 [==============================] - 5s 13ms/step - loss: 6.7875e-04 - val_loss: 8.5320e-05
# Epoch 13/30
# 355/355 [==============================] - 5s 13ms/step - loss: 6.4099e-04 - val_loss: 1.6590e-04
# Epoch 14/30
# 355/355 [==============================] - 5s 13ms/step - loss: 5.8231e-04 - val_loss: 4.1479e-04
# 39/39 [==============================] - 0s 10ms/step - loss: 6.0484e-04 - val_loss: 6.1905e-05
# Epoch 11/30
# 39/39 [==============================] - 0s 10ms/step - loss: 5.1238e-04 - val_loss: 6.2205e-05
# Epoch 12/30
# 39/39 [==============================] - 0s 10ms/step - loss: 5.5451e-04 - val_loss: 7.0418e-05
# Epoch 13/30
# 39/39 [==============================] - 0s 10ms/step - loss: 5.3408e-04 - val_loss: 1.2263e-04
# Epoch 14/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.7172e-04 - val_loss: 8.7609e-05
# Epoch 15/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.5410e-04 - val_loss: 8.5070e-05
# Epoch 16/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.7451e-04 - val_loss: 5.9564e-05
# Epoch 17/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.7720e-04 - val_loss: 6.0797e-05
# Epoch 18/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.4507e-04 - val_loss: 5.7310e-05
# Epoch 19/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.7110e-04 - val_loss: 5.8440e-05
# Epoch 20/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.1693e-04 - val_loss: 5.7189e-05
# Epoch 21/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.7655e-04 - val_loss: 1.2905e-04
# Epoch 22/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.5764e-04 - val_loss: 8.0136e-05
# Epoch 23/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.1851e-04 - val_loss: 9.3971e-05
# Epoch 24/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.6078e-04 - val_loss: 8.7564e-05
# Epoch 25/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.0465e-04 - val_loss: 8.1134e-05
# Epoch 26/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.2012e-04 - val_loss: 7.7368e-05
# Epoch 27/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.5435e-04 - val_loss: 8.9617e-05
# Epoch 28/30
# 39/39 [==============================] - 0s 10ms/step - loss: 3.8398e-04 - val_loss: 5.6326e-05
# Epoch 29/30
# 39/39 [==============================] - 0s 10ms/step - loss: 3.7952e-04 - val_loss: 6.6791e-05
# Epoch 30/30
# 39/39 [==============================] - 0s 10ms/step - loss: 4.2423e-04 - val_loss: 1.2913e-04
# 39/39 [==============================] - 0s 1ms/step
# Validation MSE: 7.106201925967735, MAE: 1.4253673143425956, R2: 0.9977628360570474
# Iteration: 7, window_size=15, batch_size=256, epochs=30, units=6, lstm_layers=3
# Epoch 1/30
# 20/20 [==============================] - 3s 29ms/step - loss: 0.0299 - val_loss: 0.0072
# Epoch 2/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0012
# Epoch 3/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0087 - val_loss: 9.8943e-04
# Epoch 4/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 7.6194e-04
# Epoch 5/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 4.9279e-04
# Epoch 6/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0069 - val_loss: 5.2881e-04
# Epoch 7/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 3.4571e-04
# Epoch 8/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 4.5919e-04
# Epoch 9/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 4.3745e-04
# Epoch 10/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 5.0865e-04
# Epoch 11/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 5.8740e-04
# Epoch 12/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 3.8376e-04
# Epoch 13/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0054 - val_loss: 3.3764e-04
# Epoch 14/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 5.1996e-04
# Epoch 15/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 4.1198e-04
# Epoch 16/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 4.4944e-04
# Epoch 17/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 2.8314e-04
# Epoch 18/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 3.2054e-04
# Epoch 19/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 4.7397e-04
# Epoch 20/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 3.6599e-04
# Epoch 21/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 4.4253e-04
# Epoch 22/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 3.1043e-04
# Epoch 23/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 2.1748e-04
# Epoch 24/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 4.6279e-04
# Epoch 25/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 2.4944e-04
# Epoch 26/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 2.7380e-04
# Epoch 27/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 2.9726e-04
# Epoch 28/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 2.3158e-04
# Epoch 29/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 3.2516e-04
# Epoch 30/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 3.7510e-04
# 39/39 [==============================] - 0s 1ms/step
# Validation MSE: 20.641956224793145, MAE: 3.575696308968343, R2: 0.9936237442095007
# Iteration: 8, window_size=5, batch_size=512, epochs=30, units=12, lstm_layers=3
# Epoch 1/30
# 10/10 [==============================] - 2s 51ms/step - loss: 0.0748 - val_loss: 0.0576
# Epoch 2/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0498 - val_loss: 0.0369
# Epoch 3/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0239
# Epoch 4/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0209 - val_loss: 0.0093
# Epoch 5/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 7.5982e-04
# Epoch 6/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 7.5918e-04
# Epoch 7/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 5.0760e-04
# Epoch 8/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 3.1236e-04
# Epoch 9/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 3.9759e-04
# Epoch 10/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 3.8183e-04
# Epoch 11/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 2.4670e-04
# Epoch 12/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 2.6897e-04
# Epoch 13/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 2.6685e-04
# Epoch 14/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 2.4550e-04
# Epoch 15/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 3.9099e-04
# Epoch 16/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 2.2085e-04
# Epoch 17/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 3.3149e-04
# Epoch 18/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 2.4234e-04
# Epoch 19/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 2.5972e-04
# Epoch 20/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 2.3828e-04
# Epoch 21/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 2.1459e-04
# Epoch 22/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 2.0116e-04
# Epoch 23/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 2.1791e-04
# Epoch 24/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 2.1167e-04
# Epoch 25/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 2.6501e-04
# Epoch 26/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 1.9774e-04
# Epoch 27/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 2.2332e-04
# Epoch 28/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 1.9977e-04
# Epoch 29/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 2.1509e-04
# Epoch 30/30
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 1.9927e-04
# 39/39 [==============================] - 0s 681us/step
# Validation MSE: 10.965973388928454, MAE: 2.134349372279778, R2: 0.9966957688395667
# Iteration: 9, window_size=30, batch_size=512, epochs=30, units=5, lstm_layers=3
# Epoch 1/30
# 10/10 [==============================] - 2s 62ms/step - loss: 0.1277 - val_loss: 0.0953
# Epoch 2/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0928 - val_loss: 0.0730
# Epoch 3/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0753 - val_loss: 0.0605
# Epoch 4/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0651 - val_loss: 0.0522
# Epoch 5/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0559 - val_loss: 0.0442
# Epoch 6/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0479 - val_loss: 0.0338
# Epoch 7/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0359 - val_loss: 0.0212
# Epoch 8/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0267 - val_loss: 0.0109
# Epoch 9/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0200 - val_loss: 0.0058
# Epoch 10/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0184 - val_loss: 0.0042
# Epoch 11/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0155 - val_loss: 0.0036
# Epoch 12/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0159 - val_loss: 0.0029
# Epoch 13/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0140 - val_loss: 0.0027
# Epoch 14/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0144 - val_loss: 0.0021
# Epoch 15/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0114 - val_loss: 0.0024
# Epoch 16/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0129 - val_loss: 0.0019
# Epoch 17/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0117 - val_loss: 0.0016
# Epoch 18/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0108 - val_loss: 0.0019
# Epoch 19/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0111 - val_loss: 0.0019
# Epoch 20/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0105 - val_loss: 0.0014
# Epoch 21/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0096 - val_loss: 0.0015
# Epoch 22/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0098 - val_loss: 0.0016
# Epoch 23/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0011
# Epoch 24/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0017
# Epoch 25/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0011
# Epoch 26/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0015
# Epoch 27/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0016
# Epoch 28/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0011
# Epoch 29/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0012
# Epoch 30/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0016
# 39/39 [==============================] - 0s 1ms/step
# Validation MSE: 86.73943228027476, MAE: 6.495627070639784, R2: 0.9726928206725312
# Iteration: 10, window_size=1, batch_size=256, epochs=30, units=1, lstm_layers=3
# Epoch 1/30
# 20/20 [==============================] - 3s 23ms/step - loss: 0.0880 - val_loss: 0.0810
# Epoch 2/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0812 - val_loss: 0.0751
# Epoch 3/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0755 - val_loss: 0.0703
# Epoch 4/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0710 - val_loss: 0.0666
# Epoch 5/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0674 - val_loss: 0.0638
# Epoch 6/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0649 - val_loss: 0.0619
# Epoch 7/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0630 - val_loss: 0.0604
# Epoch 8/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0618 - val_loss: 0.0594
# Epoch 9/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0605 - val_loss: 0.0586
# Epoch 10/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0598 - val_loss: 0.0579
# Epoch 11/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0594 - val_loss: 0.0570
# Epoch 12/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0581 - val_loss: 0.0559
# Epoch 13/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0572 - val_loss: 0.0544
# Epoch 14/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0552 - val_loss: 0.0525
# Epoch 15/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0533 - val_loss: 0.0500
# Epoch 16/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0507 - val_loss: 0.0468
# Epoch 17/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0477 - val_loss: 0.0431
# Epoch 18/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0445 - val_loss: 0.0391
# Epoch 19/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0423 - val_loss: 0.0349
# Epoch 20/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0396 - val_loss: 0.0310
# Epoch 21/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0361 - val_loss: 0.0272
# Epoch 22/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0357 - val_loss: 0.0240
# Epoch 23/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0214
# Epoch 24/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0325 - val_loss: 0.0193
# Epoch 25/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0312 - val_loss: 0.0175
# Epoch 26/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0317 - val_loss: 0.0162
# Epoch 27/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0323 - val_loss: 0.0154
# Epoch 28/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0310 - val_loss: 0.0147
# Epoch 29/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0313 - val_loss: 0.0142
# Epoch 30/30
# 20/20 [==============================] - 0s 1ms/step - loss: 0.0336 - val_loss: 0.0139
# 39/39 [==============================] - 0s 484us/step
# Validation MSE: 763.5203411191555, MAE: 18.65326841910457, R2: 0.7681979325892129
# Iteration: 11, window_size=30, batch_size=256, epochs=30, units=32, lstm_layers=1
# Epoch 1/30
# 20/20 [==============================] - 1s 18ms/step - loss: 0.0628 - val_loss: 0.0069
# Epoch 2/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0081 - val_loss: 0.0014
# Epoch 3/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 2.9567e-04
# Epoch 4/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 4.4420e-04
# Epoch 5/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0030 - val_loss: 3.8262e-04
# Epoch 6/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0026 - val_loss: 2.5705e-04
# Epoch 7/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 1.7541e-04
# Epoch 8/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 1.5711e-04
# Epoch 9/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 1.5442e-04
# Epoch 10/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 1.6518e-04
# Epoch 11/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 1.6973e-04
# Epoch 12/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 1.4988e-04
# Epoch 13/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 1.4835e-04
# Epoch 14/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 1.7859e-04
# Epoch 15/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 1.0681e-04
# Epoch 16/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 1.0049e-04
# Epoch 17/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 1.4436e-04
# Epoch 18/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 9.7505e-05
# Epoch 19/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 1.2013e-04
# Epoch 20/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 1.7223e-04
# Epoch 21/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 1.0381e-04
# Epoch 22/30
# 20/20 [==============================] - 0s 9ms/step - loss: 9.8825e-04 - val_loss: 1.0128e-04
# Epoch 23/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 1.0622e-04
# Epoch 24/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 9.9625e-05
# Epoch 25/30
# 20/20 [==============================] - 0s 9ms/step - loss: 9.8984e-04 - val_loss: 8.5102e-05
# Epoch 26/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 2.0118e-04
# Epoch 27/30
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss:
30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 3.0939e-04
# Epoch 3/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 4.5462e-04
# Epoch 4/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 1.8894e-04
# Epoch 5/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 3.9000e-04
# Epoch 6/30
# ...
# 39/39 [==============================] - 0s 610us/step
# Validation MSE: 18.971227962938222, MAE: 2.514972445993037, R2: 0.9942836517686507
# Iteration: 20, window_size=20, batch_size=256, epochs=30, units=32, lstm_layers=1
# Epoch 1/30
# 20/20 [==============================] - 1s 15ms/step - loss: 0.0568 - val_loss: 0.0093
# Epoch 2/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0014
# Epoch 3/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 2.4308e-04
# Epoch 4/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 1.8697e-04
# Epoch 5/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 1.4850e-04
# Epoch 6/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 1.3070e-04
# Epoch 7/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 1.1344e-04
# Epoch 8/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 1.1407e-04
# Epoch 9/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 9.6943e-05
# Epoch 10/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 1.3097e-04
# Epoch 11/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 1.1946e-04
# Epoch 12/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 8.6475e-05
# Epoch 13/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 8.8376e-05
# Epoch 14/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 9.9924e-05
# Epoch 15/30
# 20/20 [==============================] - 0s 6ms/step - loss: 9.9639e-04 - val_loss: 7.8076e-05
# Epoch 16/30
# 20/20 [==============================] - 0s 6ms/step - loss: 9.8321e-04 - val_loss: 1.4694e-04
# Epoch 17/30
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 7.5157e-05
# Epoch 18/30
# 20/20 [==============================] - 0s 6ms/step - loss: 9.2777e-04 - val_loss: 9.4068e-05
# Epoch 19/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.9272e-04 - val_loss: 7.5073e-05
# Epoch 20/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.6575e-04 - val_loss: 1.1003e-04
# Epoch 21/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.5478e-04 - val_loss: 1.4663e-04
# Epoch 22/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.8389e-04 - val_loss: 7.6217e-05
# Epoch 23/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.9683e-04 - val_loss: 2.2679e-04
# Epoch 24/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.6550e-04 - val_loss: 7.3659e-05
# Epoch 25/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.1716e-04 - val_loss: 8.6845e-05
# Epoch 26/30
# 20/20 [==============================] - 0s 6ms/step - loss: 7.9759e-04 - val_loss: 7.4026e-05
# Epoch 27/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.0564e-04 - val_loss: 1.1640e-04
# Epoch 28/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.7039e-04 - val_loss: 1.9230e-04
# Epoch 29/30
# 20/20 [==============================] - 0s 6ms/step - loss: 7.2631e-04 - val_loss: 7.9651e-05
# Epoch 30/30
# 20/20 [==============================] - 0s 6ms/step - loss: 8.5467e-04 - val_loss: 7.9273e-05
# 39/39 [==============================] - 0s 656us/step
# Validation MSE: 4.36242242068608, MAE: 1.1543853677905143, R2: 0.9986985393599402
# Iteration: 21, window_size=5, batch_size=14, epochs=30, units=32, lstm_layers=1
# Epoch 1/30
# 356/356 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 1.1334e-04
# Epoch 2/30
# 356/356 [==============================] - 0s 852us/step - loss: 9.3618e-04 - val_loss: 1.1555e-04
# Epoch 16/30
# 10/10 [==============================] - 1s 109ms/step - loss: 4.5988e-04 - val_loss: 7.2811e-05
# Epoch 17/30
# 10/10 [==============================] - 1s 107ms/step - loss: 4.7850e-04 - val_loss: 7.2544e-05
# Epoch 18/30
# 10/10 [==============================] - 1s 107ms/step - loss: 4.7425e-04 - val_loss: 7.1547e-05
# Epoch 19/30
# 10/10 [==============================] - 1s 107ms/step - loss: 4.2157e-04 - val_loss: 7.2035e-05
# Epoch 20/30
# 10/10 [==============================] - 1s 108ms/step - loss: 4.1502e-04 - val_loss: 7.1461e-05
# Epoch 21/30
# 10/10 [==============================] - 1s 118ms/step - loss: 4.1389e-04 - val_loss: 7.0742e-05
# Epoch 22/30
# 10/10 [==============================] - 1s 112ms/step - loss: 3.9135e-04 - val_loss: 7.7303e-05
# Epoch 23/30
# 10/10 [==============================] - 1s 109ms/step - loss: 4.1295e-04 - val_loss: 7.4446e-05
# Epoch 24/30
# 10/10 [==============================] - 1s 111ms/step - loss: 3.9751e-04 - val_loss: 6.9390e-05
# Epoch 25/30
# 10/10 [==============================] - 1s 108ms/step - loss: 3.7837e-04 - val_loss: 7.2882e-05
# Epoch 26/30
# 10/10 [==============================] - 1s 110ms/step - loss: 3.5146e-04 - val_loss: 6.8174e-05
# Epoch 27/30
# 10/10 [==============================] - 1s 112ms/step - loss: 3.6156e-04 - val_loss: 7.4111e-05
# Epoch 28/30
# 10/10 [==============================] - 1s 114ms/step - loss: 3.8443e-04 - val_loss: 6.7365e-05
# Epoch 29/30
# 10/10 [==============================] - 1s 113ms/step - loss: 3.5060e-04 - val_loss: 7.6833e-05
# Epoch 30/30
# 10/10 [==============================] - 1s 112ms/step - loss: 3.3297e-04 - val_loss: 7.1930e-05
# 39/39 [==============================] - 0s 6ms/step
# Validation MSE: 3.958322468020229, MAE: 0.9893579199608521, R2: 0.9988368241508433
# Iteration: 25, window_size=30, batch_size=256, epochs=30, units=32, lstm_layers=1
# Modell mit den Parametern (ws=30, bs=256, ep=30, units=32, layers=1) existiert bereits. Überspringe...
# Iteration: 26, window_size=20, batch_size=5, epochs=30, units=1, lstm_layers=1
# Epoch 1/30
# 994/994 [==============================] - 3s 2ms/step - loss: 0.0172 - val_loss: 0.0026
# Epoch 2/30
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0129 - val_loss: 0.0025
# Epoch 3/30
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0126 - val_loss: 0.0024
# Epoch 4/30
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0121 - val_loss: 0.0024
# Epoch 5/30
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0123 - val_loss: 0.0025
# Epoch 6/30
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0118 - val_loss: 0.0027
# Epoch 7/30
# 363/994 [=========>....................] - ETA: 0s - loss: 0.0134

# %%
def plot_predictions_from_models(X_data, y_data, data_type, model_names=None, csv_filename='./results/hyperparameter_search_results.csv', save_fig=True):
    """
    Diese Funktion plotet die Vorhersagen ausgewählter Modelle gegen den echten Kurs.
    :param X_data: Die Eingangsdaten (Features).
    :param y_data: Die echten Zielwerte (z.B. Aktienkurs).
    :param data_type: Typ der Daten ('Train', 'Test').
    :param model_names: Liste von Modellnamen oder einzelner Modellname. Wenn None, werden alle Modelle aus der CSV-Datei verwendet.
    :param csv_filename: Pfad zur CSV-Datei mit Modellinformationen.
    :param save_fig: Wenn True, wird die Figur gespeichert.
    """
    
    # Scaler laden
    scaler = joblib.load('./scaler/scaler.pkl')
    
    # CSV-Datei laden
    df = pd.read_csv(csv_filename)
    
    # Wenn keine Modellnamen übergeben werden, alle Modelle aus der CSV verwenden
    if model_names is None:
        model_names = df['Model Name'].tolist()
    elif isinstance(model_names, str):  # Falls nur ein einzelner Modellname übergeben wird
        model_names = [model_names]

    # Rückskalieren der echten Werte
    y_data_rescaled = scaler.inverse_transform(y_data.reshape(-1, 1))

    # Erstelle einen Plotly-Plot
    fig = go.Figure()

    # Füge die echten Werte hinzu
    fig.add_trace(go.Scatter(y=y_data_rescaled.flatten(), mode='lines', name=f'Echte {data_type} Werte', line=dict(color='black')))

    # Vorhersagen der ausgewählten Modelle plotten
    for model_name in model_names:
        if model_name in df['Model Name'].values:
            # Extrahiere den window_size aus dem Modellnamen (z.B. 'model_20211010-101010_ws30_bs32_...')
            window_size = int(model_name.split('_ws')[1].split('_')[0])

            # Bereite die Daten für das Modell mit der extrahierten window_size vor
            X_windowed = create_windowed_data_for_model(X_data, window_size)

            # Lade das Modell
            model = load_model(f'./models/{model_name}', compile=False)

            # Vorhersagen machen
            y_pred = model.predict(X_windowed)
            y_pred_rescaled = scaler.inverse_transform(y_pred)

            # Modellvorhersage in den Plot einfügen
            fig.add_trace(go.Scatter(y=y_pred_rescaled.flatten(), mode='lines', name=f'{model_name}', line=dict(width=1)))
        else:
            print(f"Modell {model_name} wurde in der CSV-Datei nicht gefunden.")

    # Layout des Plots
    fig.update_layout(
        title=f'Vorhersagen der Modelle auf {data_type}daten',
        xaxis_title='Zeit',
        yaxis_title='Preis',
        showlegend=True
    )

    # Plot anzeigen
    fig.show(renderer='browser')
    
    # Optionales Speichern des Plots
    if save_fig:
        fig.write_html(f"./plots/{time.strftime('%Y%m%d-%H%M%S')}.html")


def create_windowed_data_for_model(X_data, window_size):
    """
    Bereitet die Daten so vor, dass sie für Modelle mit unterschiedlicher window_size verwendet werden können.
    :param X_data: Originale Daten, die vorfenstert werden sollen.
    :param window_size: Die Fenstergröße, die für das Modell verwendet wurde.
    :return: Fensterartige Daten für das Modell.
    """
    X_windowed = []
    for i in range(window_size, len(X_data)):
        X_windowed.append(X_data[i - window_size:i])
    return np.array(X_windowed)

# %%
plot_predictions_from_models(scaled_features, scaled_target, data_type='Prediction')
# Out:
# 193/193 [==============================] - 0s 1ms/step
# 195/195 [==============================] - 1s 2ms/step
# 195/195 [==============================] - 0s 364us/step
# 195/195 [==============================] - 0s 441us/step
# 195/195 [==============================] - 1s 991us/step
# 194/194 [==============================] - 1s 4ms/step
# 194/194 [==============================] - 0s 1ms/step
# 195/195 [==============================] - 1s 874us/step
# 195/195 [==============================] - 1s 565us/step
# 194/194 [==============================] - 1s 1ms/step
# 195/195 [==============================] - 0s