# %%
import os
import time
import csv
import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import save_model, load_model
from keras.callbacks import EarlyStopping
import plotly.express as px
import plotly.graph_objs as go
import joblib

# Erstelle den Ordner zum Speichern der Modelle, falls nicht bereits vorhanden
os.makedirs('./models', exist_ok=True)

# %%
# Lade die historischen Daten einer Aktie (z.B. Apple)
symbol = "AAPL"  # Apple-Aktien
start_date = "2000-01-01"  # Startdatum für die Daten
end_date = "2024-10-10"    # Enddatum für die Daten

# CSV-Datei für die Ergebnisse
csv_filename = f'./results/hyperparameter_search_results_{start_date}_{end_date}.csv'
os.makedirs('./results', exist_ok=True)

# Daten herunterladen von Yahoo Finance
df = yf.download(symbol, start=start_date, end=end_date)

# Überprüfen der Daten
print(df.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2000-01-03  0.936384  1.004464  0.907924  0.999442   0.844004  535796800
# 2000-01-04  0.966518  0.987723  0.903460  0.915179   0.772846  512377600
# 2000-01-05  0.926339  0.987165  0.919643  0.928571   0.784155  778321600
# 2000-01-06  0.947545  0.955357  0.848214  0.848214   0.716296  767972800
# 2000-01-07  0.861607  0.901786  0.852679  0.888393   0.750226  460734400

# %%
# Daten aus den relevanten Spalten entnehmen
features = df[['Open', 'High', 'Low', 'Adj Close', 'Volume']]
target = df['Close']

# MinMaxScaler initialisieren und die Features skalieren
feature_scaler = MinMaxScaler(feature_range=(0, 1))
target_scaler = MinMaxScaler(feature_range=(0, 1))

scaled_features = feature_scaler.fit_transform(features)
scaled_target = target_scaler.fit_transform(target.values.reshape(-1, 1))

joblib.dump(feature_scaler, './scaler/feature_scaler.pkl')
joblib.dump(target_scaler, './scaler/target_scaler.pkl')
# Out:
# ['./scaler/target_scaler.pkl']

# %%
val_size= 0.2
# Definiere die möglichen Werte für die Hyperparameter
hyperparameters = {
    'windowsize': [1, 2, 5, 10, 15, 20, 30, 60],
    'batchsize': [1, 5, 14, 30, 64, 128, 256, 512],
    'epochs': [30],
    'units': [1, 2, 5, 6, 8, 12, 16, 32, 64, 128],
    'lstm_layers': [1, 2, 3]
}

# %%
# Prüfe, ob das Modell bereits existiert
def model_exists(window_size, batch_size, epochs, units, lstm_layers):
    if os.path.exists(csv_filename):
        with open(csv_filename, 'r') as file:
            reader = csv.reader(file)
            for row in reader:
                if row[1:6] == [str(window_size), str(batch_size), str(epochs), str(units), str(lstm_layers)]:
                    return True
    return False

# Schreibe oder appende die Ergebnisse in die CSV
def write_to_csv(model_name, window_size, batch_size, epochs, units, lstm_layers, mse, mae, r2):
    file_exists = os.path.isfile(csv_filename)
    with open(csv_filename, 'a', newline='') as file:
        writer = csv.writer(file)
        if not file_exists:
            # Header hinzufügen, wenn die Datei neu erstellt wird
            writer.writerow(['Model Name', 'Window Size', 'Batch Size', 'Epochs', 'Units', 'LSTM Layers', 'MSE', 'MAE', 'R2'])
        writer.writerow([model_name, window_size, batch_size, epochs, units, lstm_layers, mse, mae, r2])

def create_windowed_data(features, target, window_size=60):
    X, y = [], []
    for i in range(window_size, len(features)):
        X.append(features[i-window_size:i])
        y.append(target[i])
    return np.array(X), np.array(y)

# Zufällige Suche über die Hyperparameter
def random_search(n_iter=10):
    results = []

    for _ in range(n_iter):
        # Zufällige Auswahl von Hyperparametern
        window_size = np.random.choice(hyperparameters['windowsize'])
        batch_size = np.random.choice(hyperparameters['batchsize'])
        epochs = np.random.choice(hyperparameters['epochs'])
        units = int(np.random.choice(hyperparameters['units']))
        lstm_layers = np.random.choice(hyperparameters['lstm_layers'])

        print(f"Iteration: {_}, window_size={window_size}, batch_size={batch_size}, epochs={epochs}, units={units}, lstm_layers={lstm_layers}")

        # Prüfe, ob das Modell mit diesen Parametern bereits existiert
        if model_exists(window_size, batch_size, epochs, units, lstm_layers):
            print(f"Modell mit den Parametern (ws={window_size}, bs={batch_size}, ep={epochs}, units={units}, layers={lstm_layers}) existiert bereits. Überspringe...")
            continue

        # Daten vorbereiten mit aktuellem window_size
        X, y = create_windowed_data(scaled_features, scaled_target, window_size=window_size)
        X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=val_size, random_state=42)

        # Modell erstellen
        model = Sequential()

        # Ersten LSTM Layer hinzufügen
        model.add(LSTM(units=units, return_sequences=True if lstm_layers > 1 else False, input_shape=(X_train.shape[1], X_train.shape[2])))
        model.add(Dropout(0.2))

        # Weitere LSTM Layer falls vorhanden
        for layer in range(1, lstm_layers):
            model.add(LSTM(units=units, return_sequences=False if layer == lstm_layers - 1 else True))
            model.add(Dropout(0.2))

        # Dense-Schicht hinzufügen
        model.add(Dense(units=1))

        # Modell kompilieren
        model.compile(optimizer='adam', loss='mean_squared_error')
        earlystop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        # Modell trainieren
        history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=1, callbacks=[earlystop])

        # Vorhersagen auf den Validierungsdaten
        y_pred = model.predict(X_val)

        # Den Skalierungsfaktor rückgängig machen, um die echten Werte wiederherzustellen
        y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))
        y_pred_rescaled = scaler.inverse_transform(y_pred)

        # Berechne die Metriken
        mse = mean_squared_error(y_val_true, y_pred_rescaled)
        mae = mean_absolute_error(y_val_true, y_pred_rescaled)
        r2 = r2_score(y_val_true, y_pred_rescaled)

        # Ergebnisse ausgeben
        print(f"Validation MSE: {mse}, MAE: {mae}, R2: {r2}")

        # Modellname basierend auf einem Zeitstempel
        timestamp = time.strftime("%Y%m%d-%H%M%S")
        model_name = f"model_{timestamp}_ws{window_size}_bs{batch_size}_epochs{epochs}_units{units}_layers{lstm_layers}.keras"
        save_model(model, f'./models/{model_name}')

        # Ergebnis in die CSV-Datei schreiben
        write_to_csv(model_name, window_size, batch_size, epochs, units, lstm_layers, mse, mae, r2)

        # Ergebnis in die Resultsliste einfügen
        results.append((window_size, batch_size, epochs, units, lstm_layers, mse, mae, r2, model_name))

    # Ergebnisse sortieren nach dem besten MSE
    results = sorted(results, key=lambda x: x[5])  # Sortiere nach MSE
    best_params = results[0]

    print("\nBeste Hyperparameter-Kombination:")
    print(f"window_size={best_params[0]}, batch_size={best_params[1]}, epochs={best_params[2]}, units={best_params[3]}, lstm_layers={best_params[4]}")

    return results

# %%
# Beispielhafte Ausführung der Funktion
results = random_search(n_iter=53)
# Out:
# Iteration: 0, window_size=1, batch_size=14, epochs=30, units=16, lstm_layers=1
# Epoch 1/30
30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0086 - val_loss: 0.0020
# Epoch 24/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0085 - val_loss: 0.0019
# Epoch 25/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0019
# Epoch 26/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0083 - val_loss: 0.0017
# Epoch 27/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0079 - val_loss: 0.0016
# Epoch 28/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0015
# Epoch 29/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0079 - val_loss: 0.0015
# Epoch 30/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0078 - val_loss: 0.0016
# 39/39 [==============================] - 0s 446us/step
# Validation MSE: 86.22188772095399, MAE: 6.719873307915599, R2: 0.9740199033852665
# Iteration: 2, window_size=60, batch_size=512, epochs=30, units=2, lstm_layers=2
# Epoch 1/30
# 10/10 [==============================] - 2s 46ms/step - loss: 0.0425 - val_loss: 0.0306
# Epoch 2/30
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0302 - val_loss: 0.0216
# Epoch 3/30
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0234 - val_loss: 0.0165
# Epoch 4/30
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0234 - val_loss: 0.0119
# Epoch 5/30
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0165 - val_loss: 0.0087
# Epoch 6/30
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0150 - val_loss: 0.0066
# Epoch 7/30
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0136 - val_loss: 0.0050
# Epoch 8/30
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0131 - val_loss: 0.0043
# Epoch 9/30
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0143 - val_loss: 0.0039
# Epoch 10/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0127 - val_loss: 0.0036
# Epoch 11/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0128 - val_loss: 0.0033
# Epoch 12/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0123 - val_loss: 0.0031
# Epoch 13/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0115 - val_loss: 0.0029
# Epoch 14/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0101 - val_loss: 0.0027
# Epoch 15/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0108 - val_loss: 0.0026
# Epoch 16/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0098 - val_loss: 0.0025
# Epoch 17/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0109 - val_loss: 0.0023
# Epoch 18/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0104 - val_loss: 0.0021
# Epoch 19/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0105 - val_loss: 0.0020
# Epoch 20/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0020
# Epoch 21/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0102 - val_loss: 0.0019
# Epoch 22/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0019
# Epoch 23/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0090 - val_loss: 0.0018
# Epoch 24/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0093 - val_loss: 0.0018
# Epoch 25/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0091 - val_loss: 0.0018
# Epoch 26/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0091 - val_loss: 0.0018
# Epoch 27/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0089 - val_loss: 0.0018
# Epoch 28/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.0017
# Epoch 29/30
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0017
# Epoch 30/30
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0019
# 39/39 [==============================] - 0s 2ms/step
# Validation MSE: 102.02423785948218, MAE: 6.621637299789591, R2: 0.9700195902517947
# Iteration: 3, window_size=15, batch_size=1, epochs=30, units=32, lstm_layers=3
# Epoch 1/30
# 4973/4973 [==============================] - 15s 3ms/step - loss: 0.0025 - val_loss: 4.6494e-04
# Epoch 2/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0020 - val_loss: 0.0011
# Epoch 3/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0016 - val_loss: 1.6121e-04
# Epoch 4/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0015 - val_loss: 4.8121e-04
# Epoch 5/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 6/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0013 - val_loss: 1.8415e-04
# Epoch 7/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0013 - val_loss: 5.5312e-04
# Epoch 8/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0012 - val_loss: 7.7807e-05
# Epoch 9/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0011 - val_loss: 4.6064e-04
# Epoch 10/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0011 - val_loss: 6.2942e-05
# Epoch 11/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0010 - val_loss: 3.0815e-04
# Epoch 12/30
# 4973/4973 [==============================] - 14s 3ms/step - loss: 0.0010 - val_loss: 1.0149e-04
# Epoch 13/30
# 4973/4973 [==============================] - 14s 3ms/step - loss: 0.0011 - val_loss: 3.1295e-04
# Epoch 14/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0010 - val_loss: 3.7104e-04
# Epoch 15/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 9.7884e-04 - val_loss: 9.1526e-04
# Epoch 16/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 9.3985e-04 - val_loss: 1.1056e-04
# Epoch 17/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 0.0010 - val_loss: 4.5171e-04
# Epoch 18/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 8.8892e-04 - val_loss: 4.3368e-04
# Epoch 19/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 9.8326e-04 - val_loss: 7.0541e-04
# Epoch 20/30
# 4973/4973 [==============================] - 13s 3ms/step - loss: 8.7557e-04 - val_loss: 2.2823e-04
# 39/39 [==============================] - 0s 1ms/step
# Validation MSE: 3.4637491428949314, MAE: 1.2152564482721484, R2: 0.9989300553547975
# Iteration: 4, window_size=15, batch_size=5, epochs=30, units=64, lstm_layers=2
# Epoch 1/30
# 995/995 [==============================] - 5s 4ms/step - loss: 0.0016 - val_loss: 2.5995e-04
# Epoch 2/30
# 995/995 [==============================] - 4s 4ms/step - loss: 9.4345e-04 - val_loss: 1.7677e-04
# Epoch 3/30
# 995/995 [==============================] - 4s 4ms/step - loss: 9.1568e-04 - val_loss: 9.5519e-05
# Epoch 4/30
# 995/995 [==============================] - 4s 4ms/step - loss: 7.6913e-04 - val_loss: 1.2241e-04
# Epoch 5/30
# 995/995 [==============================] - 4s 4ms/step - loss: 7.0002e-04 - val_loss: 1.8644e-04
# Epoch 6/30
# 995/995 [==============================] - 4s 4ms/step - loss: 6.7494e-04 - val_loss: 6.2743e-05
# Epoch 7/30
# 995/995 [==============================] - 4s 4ms/step - loss: 6.6332e-04 - val_loss: 1.5434e-04
# Epoch 8/30
# 995/995 [==============================] - 4s 4ms/step - loss: 6.8170e-04 - val_loss: 9.9133e-05
# Epoch 9/30
# 995/995 [==============================] - 4s 4ms/step - loss: 5.8660e-04 - val_loss: 6.2846e-05
# Epoch 10/30
# 995/995 [==============================] - 4s 4ms/step - loss: 6.0178e-04 - val_loss: 1.9843e-04
# Epoch 11/30
# 995/995 [==============================] - 4s 4ms/step - loss: 6.1497e-04 - val_loss: 2.6680e-04
# Epoch 12/30
# 995/995 [==============================] - 4s 4ms/step - loss: 6.1028e-04 - val_loss: 9.6932e-05
# Epoch 13/30
# 995/995 [==============================] - 4s 4ms/step - loss: 5.6862e-04 - val_loss: 1.6308e-04
# Epoch 14/30
# 995/995 [==============================] - 4s 4ms/step - loss: 4.7812e-04 - val_loss: 1.1848e-04
# Epoch 15/30
# 995/995 [==============================] - 4s 4ms/step - loss: 5.4084e-04 - val_loss: 2.2712e-04
# Epoch 16/30
# 995/995 [==============================] - 4s 4ms/step - loss: 5.7251e-04 - val_loss: 2.8877e-04
# 39/39 [==============================] - 0s 1ms/step
# Validation MSE: 3.4527626568211764, MAE: 0.9869621354020485, R2: 0.9989334490566678
# Iteration: 5, window_size=20, batch_size=64, epochs=30, units=8, lstm_layers=3
# Modell mit den Parametern (ws=20, bs=64, ep=30, units=8, layers=3) existiert bereits. Überspringe...
# Iteration: 6, window_size=15, batch_size=1, epochs=30, units=32, lstm_layers=3
# Modell mit den Parametern (ws=15, bs=1, ep=30, units=32, layers=3) existiert bereits. Überspringe...
# Iteration: 7, window_size=15, batch_size=64, epochs=30, units=12, lstm_layers=3
# Epoch 1/30
# 78/78 [==============================] - 3s 13ms/step - loss: 0.0161 - val_loss: 6.6054e-04
# Epoch 2/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 3.8138e-04
# Epoch 3/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 4.6247e-04
# Epoch 4/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 3.2877e-04
# Epoch 5/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 7.6462e-04
# Epoch 6/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 4.2951e-04
# Epoch 7/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 4.7784e-04
# Epoch 8/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 3.6734e-04
# Epoch 9/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 6.2433e-04
# Epoch 10/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 2.3048e-04
# Epoch 11/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 2.2445e-04
# Epoch 12/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 2.6310e-04
# Epoch 13/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 2.3143e-04
# Epoch 14/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 2.7375e-04
# Epoch 15/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 3.7568e-04
# Epoch 16/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 2.2199e-04
# Epoch 17/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 3.4400e-04
# Epoch 18/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 4.3133e-04
# Epoch 19/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 5.9146e-04
# Epoch 20/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 2.8784e-04
# Epoch 21/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 2.2942e-04
# Epoch 22/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 4.5126e-04
# Epoch 23/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 1.9990e-04
# Epoch 24/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 1.8082e-04
# Epoch 25/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 2.3370e-04
# Epoch 26/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 2.6546e-04
# Epoch 27/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 3.1367e-04
# Epoch 28/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 1.8633e-04
# Epoch 29/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 1.8436e-04
# Epoch 30/30
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 3.2822e-04
# 39/39 [==============================] - 0s 1ms/step
# Validation MSE: 18.062287092781894, MAE: 2.536365977221938, R2: 0.9944205984447017
# Iteration: 8, window_size=2, batch_size=5, epochs=30, units=128, lstm_layers=1
# Epoch 1/30
# 997/997 [==============================] - 2s 1ms/step - loss: 0.0014 - val_loss: 6.9274e-05
# Epoch 2/30
# 997/997 [==============================] - 1s 858us/step - loss: 3.9212e-04 - val_loss: 1.0108e-04
# Epoch 3/30
# 997/997 [==============================] - 1s 868us/step - loss: 3.6554e-04 - val_loss: 1.5783e-04
# Epoch 4/30
# 997/997 [==============================] - 1s 882us/step - loss: 3.5162e-04 - val_loss: 4.4571e-05
# Epoch 5/30
# 997/997 [==============================] - 1s 856us/step - loss: 2.6997e-04 - val_loss: 2.0009e-04
# Epoch 6/30
# 997/997 [==============================] - 1s 867us/step - loss: 2.8717e-04 - val_loss: 2.0523e-04
# Epoch 7/30
# 997/997 [==============================] - 1s 863us/step - loss: 2.5663e-04 - val_loss: 4.0452e-05
# Epoch 8/30
# 997/997 [==============================] - 1s 867us/step - loss: 3.0137e-04 - val_loss: 5.5969e-05
# Epoch 9/30
# 997/997 [==============================] - 1s 866us/step - loss: 2.5643e-04 - val_loss: 4.7612e-05
# Epoch 10/30
# 997/997 [==============================] - 1s 868us/step - loss: 2.8945e-04 - val_loss: 1.1638e-04
# Epoch 11/30
# 997/997 [==============================] - 1s 880us/step - loss: 2.6026e-04 - val_loss: 5.7037e-05
# Epoch 12/30
# 997/997 [==============================] - 1s 865us/step - loss: 2.7454e-04 - val_loss: 5.7505e-05
# Epoch 13/30
# 997/997 [==============================] - 1s 876us/step - loss: 2.6974e-04 - val_loss: 1.2425e-04
# Epoch 14/30
# 997/997 [==============================] - 1s 869us/step - loss: 2.7192e-04 - val_loss: 5.2461e-05
# Epoch 15/30
# 997/997 [==============================] - 1s 869us/step - loss: 2.2224e-04 - val_loss: 7.9649e-05
# Epoch 16/30
# 997/997 [==============================] - 1s 867us/step - loss: 2.8664e-04 - val_loss: 5.6064e-05
# Epoch 17/30
# 997/997 [==============================] - 1s 867us/step - loss: 2.6519e-04 - val_loss: 3.9690e-05
# Epoch 18/30
# 997/997 [==============================] - 1s 874us/step - loss: 2.4339e-04 - val_loss: 6.1260e-05
# Epoch 19/30
# 997/997 [==============================] - 1s 881us/step - loss: 2.6305e-04 - val_loss: 4.4978e-05
# Epoch 20/30
# 997/997 [==============================] - 1s 870us/step - loss: 2.7582e-04 - val_loss: 3.8930e-05
# Epoch 21/30
# 997/997 [==============================] - 1s 870us/step - loss: 2.2120e-04 - val_loss: 4.6391e-05
# Epoch 22/30
# 997/997 [==============================] - 1s 891us/step - loss: 2.4539e-04 - val_loss: 4.8938e-05
# Epoch 23/30
# 997/997 [==============================] - 1s 877us/step - loss: 2.4255e-04 - val_loss: 8.3083e-05
# Epoch 24/30
# 997/997 [==============================] - 1s 872us/step - loss: 2.9491e-04 - val_loss: 1.5903e-04
# Epoch 25/30
# 997/997 [==============================] - 1s 872us/step - loss: 2.2430e-04 - val_loss: 5.3089e-05
# Epoch 26/30
# 997/997 [==============================] - 1s 875us/step - loss: 2.4670e-04 - val_loss: 4.4107e-05
# Epoch 27/30
# 997/997 [==============================] - 1s 874us/step - loss: 2.4116e-04 - val_loss: 7.4404e-05
# Epoch 28/30
# 997/997 [==============================] - 1s 874us/step - loss: 2.4288e-04 - val_loss: 5.4121e-05
# Epoch 29/30
# 997/997 [==============================] - 1s 874us/step - loss: 2.5043e-04 - val_loss: 1.8914e-04
# Epoch 30/30
# 997/997 [==============================] - 1s 877us/step - loss: 2.5402e-04 - val_loss: 4.3855e-05
# 39/39 [==============================] - 0s 477us/step
# Validation MSE: 2.1423358336927345, MAE: 0.7547739493222623, R2: 0.9993505851196294
# Iteration: 9, window_size=15, batch_size=256, epochs=30, units=6, lstm_layers=2
# Epoch 1/30
# 20/20 [==============================] - 2s 20ms/step - loss: 0.0507 - val_loss: 0.0241
# Epoch 2/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0223 - val_loss: 0.0073
# Epoch 3/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0102 - val_loss: 0.0012
# Epoch 4/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0073 - val_loss: 9.2151e-04
# Epoch 5/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 7.4280e-04
# Epoch 6/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 5.3013e-04
# Epoch 7/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 6.5809e-04
# Epoch 8/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 5.5289e-04
# Epoch 9/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0059 - val_loss: 4.3041e-04
# Epoch 10/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 4.9797e-04
# Epoch 11/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 3.7508e-04
# Epoch 12/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 3.4874e-04
# Epoch 13/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0053 - val_loss: 4.4414e-04
# Epoch 14/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0049 - val_loss: 4.1651e-04
# Epoch 15/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 4.0166e-04
# Epoch 16/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 4.0240e-04
# Epoch 17/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 3.3126e-04
# Epoch 18/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 3.2493e-04
# Epoch 19/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 3.4636e-04
# Epoch 20/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0043 - val_loss: 2.8569e-04
# Epoch 21/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 3.0319e-04
# Epoch 22/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 4.8208e-04
# Epoch 23/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 3.3804e-04
# Epoch 24/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 3.6104e-04
# Epoch 25/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 3.9531e-04
# Epoch 26/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 4.0813e-04
# Epoch 27/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 4.4477e-04
# Epoch 28/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 3.0810e-04
# Epoch 29/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 4.4975e-04
# Epoch 30/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.
# 10/10 [==============================] - 0s 15ms/step - loss: 6.9680e-04 - val_loss: 9.5433e-05
# Epoch 28/30
# 10/10 [==============================] - 0s 15ms/step - loss: 6.8211e-04 - val_loss: 7.6024e-05
# Epoch 29/30
# 10/10 [==============================] - 0s 15ms/step - loss: 6.8349e-04 - val_loss: 7.8840e-05
# Epoch 30/30
# 10/10 [==============================] - 0s 15ms/step - loss: 6.2445e-04 - val_loss: 7.3685e-05
# 39/39 [==============================] - 0s 826us/step
# Validation MSE: 4.054937335177141, MAE: 1.0534262531235168, R2: 0.9987781795722737
# Iteration: 13, window_size=20, batch_size=256, epochs=30, units=2, lstm_layers=1
# Epoch 1/30
# 20/20 [==============================] - 1s 12ms/step - loss: 0.1488 - val_loss: 0.1338
# Epoch 2/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1253 - val_loss: 0.1151
# Epoch 3/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1092 - val_loss: 0.1020
# Epoch 4/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0968 - val_loss: 0.0917
# Epoch 5/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0879 - val_loss: 0.0832
# Epoch 6/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0798 - val_loss: 0.0750
# Epoch 7/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0713 - val_loss: 0.0660
# Epoch 8/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0625 - val_loss: 0.0553
# Epoch 9/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0510 - val_loss: 0.0417
# Epoch 10/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0366 - val_loss: 0.0277
# Epoch 11/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0281 - val_loss: 0.0173
# Epoch 12/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0207 - val_loss: 0.0108
# Epoch 13/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0173 - val_loss: 0.0074
# Epoch 14/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0151 - val_loss: 0.0054
# Epoch 15/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0151 - val_loss: 0.0044
# Epoch 16/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0040
# Epoch 17/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0146 - val_loss: 0.0038
# Epoch 18/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0145 - val_loss: 0.0036
# Epoch 19/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0132 - val_loss: 0.0035
# Epoch 20/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0145 - val_loss: 0.0034
# Epoch 21/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0034
# Epoch 22/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0034
# Epoch 23/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.0032
# Epoch 24/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0032
# Epoch 25/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0032
# Epoch 26/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0123 - val_loss: 0.0032
# Epoch 27/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0030
# Epoch 28/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0146 - val_loss: 0.0030
# Epoch 29/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0030
# Epoch 30/30
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0029
# 39/39 [==============================] - 0s 540us/step
# Validation MSE: 161.16835395560798, MAE: 9.08448661715152, R2: 0.9519179371301109
# Iteration: 14, window_size=10, batch_size=128, epochs=30, units=2, lstm_layers=1
# Epoch 1/30
# 39/39 [==============================] - 1s 6ms/step - loss: 0.1028 - val_loss: 0.0764
# Epoch 2/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0804 - val_loss: 0.0638
# Epoch 3/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0695 - val_loss: 0.0565
# Epoch 4/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0617 - val_loss: 0.0501
# Epoch 5/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0525 - val_loss: 0.0406
# Epoch 6/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0383 - val_loss: 0.0241
# Epoch 7/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0214 - val_loss: 0.0079
# Epoch 8/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0023
# Epoch 9/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0083 - val_loss: 0.0015
# Epoch 10/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0079 - val_loss: 0.0014
# Epoch 11/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0083 - val_loss: 0.0013
# Epoch 12/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0078 - val_loss: 0.0014
# Epoch 13/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0088 - val_loss: 0.0013
# Epoch 14/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0092 - val_loss: 0.0012
# Epoch 15/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0012
# Epoch 16/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0012
# Epoch 17/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 18/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0078 - val_loss: 0.0014
# Epoch 19/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0076 - val_loss: 0.0011
# Epoch 20/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0073 - val_loss: 0.0013
# Epoch 21/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0073 - val_loss: 0.0012
# Epoch 22/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0083 - val_loss: 0.0012
# Epoch 23/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0079 - val_loss: 0.0010
# Epoch 24/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0076 - val_loss: 0.0012
# Epoch 25/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0012
# Epoch 26/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0071 - val_loss: 0.0013
# Epoch 27/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0069 - val_loss: 0.0011
# Epoch 28/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0074 - val_loss: 0.0011
# Epoch 29/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0075 - val_loss: 0.0010
# Epoch 30/30
# 39/39 [==============================] - 0s 1ms/step - loss: 0.0069 - val_loss: 0.0011
# 39/39 [==============================] - 0s 447us/step
# Validation MSE: 58.116292101403566, MAE: 5.8141455311253365, R2: 0.9808387420079692
# Iteration: 15, window_size=10, batch_size=128, epochs=30, units=2, lstm_layers=2
# Epoch 1/30
# 39/39 [==============================] - 2s 10ms/step - loss: 0.0811 - val_loss: 0.0500
# Epoch 2/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0513 - val_loss: 0.0343
# Epoch 3/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0321 - val_loss: 0.0132
# Epoch 4/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0151 - val_loss: 0.0018
# Epoch 5/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0011
# Epoch 6/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0105 - val_loss: 0.0011
# Epoch 7/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0012
# Epoch 8/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0101 - val_loss: 0.0012
# Epoch 9/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0011
# Epoch 10/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 7.7412e-04
# Epoch 11/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0012
# Epoch 12/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 5.6161e-04
# Epoch 13/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 7.9555e-04
# Epoch 14/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 7.6583e-04
# Epoch 15/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 8.3601e-04
# Epoch 16/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 5.1670e-04
# Epoch 17/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 8.7228e-04
# Epoch 18/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 7.1662e-04
# Epoch 19/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0010
# Epoch 20/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 7.5828e-04
# Epoch 21/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 7.4225e-04
# Epoch 22/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 6.1770e-04
# Epoch 23/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 7.8068e-04
# Epoch 24/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 7.3514e-04
# Epoch 25/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0088 - val_loss: 6.9301e-04
# Epoch 26/30
# 39/39 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 6.4812e-04
# 39/39 [==============================] - 0s 662us/step
# Validation MSE: 28.43400799405064, MAE: 3.9856239883176774, R2: 0.9906251527201558
# Iteration: 16, window_size=1, batch_size=5, epochs=30, units=16, lstm_layers=2
# Epoch 1/30
# 997/997 [==============================] - 3s 1ms/step - loss: 0.0116 - val_loss: 2.4244e-04
# Epoch 2/30
# 997/997 [==============================] - 1s 798us/step - loss: 0.0027 - val_loss: 1.3720e-04
# Epoch 3/30
# 997/997 [==============================] - 1s 797us/step - loss: 0.0021 - val_loss: 1.0121e-04
# Epoch 4/30
# 997/997 [==============================] - 1s 798us/step - loss: 0.0020 - val_loss: 1.8258e-04
# Epoch 5/30
# 997/997 [==============================] - 1s 796us/step - loss: 0.0017 - val_loss: 1.4661e-04
# Epoch 6/30
# 997/997 [==============================] - 1s 797us/step - loss: 0.0019 - val_loss: 4.1858e-04
# Epoch 7/30
# 997/997 [==============================] - 1s 801us/step - loss: 0.0018 - val_loss: 1.7400e-04
# Epoch 8/30
# 997/997 [==============================] - 1s 790us/step - loss: 0.0017 - val_loss: 2.7129e-04
# Epoch 9/30
# 997/997 [==============================] - 1s 779us/step - loss: 0.0018 - val_loss: 1.7771e-04
# Epoch 10/30
# 997/997 [==============================] - 1s 798us/step - loss: 0.0018 - val_loss: 2.4656e-04
# Epoch 11/30
# 997/997 [==============================] - 1s 799us/step - loss: 0.0018 - val_loss: 3.1304e-04
# Epoch 12/30
# 997/997 [==============================] - 1s 795us/step - loss: 0.0018 - val_loss: 1.8005e-04
# Epoch 13/30
# 997/997 [==============================] - 1s 798us/step - loss: 0.0017 - val_loss: 2.0177e-04
# 39/39 [==============================] - 0s 415us/step
# Validation MSE: 5.569828247943881, MAE: 1.5500061930255828, R2: 0.9983090198997135
# Iteration: 17, window_size=15, batch_size=256, epochs=30, units=8, lstm_layers=2
# Epoch 1/30
# 20/20 [==============================] - 2s 20ms/step - loss: 0.0506 - val_loss: 0.0184
# Epoch 2/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0159 - val_loss: 0.0025
# Epoch 3/30
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0076 - val_loss: 0.0013
# Epoch 4/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0066 - val_loss: 9.4115e-04
# Epoch 5/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 6.3597e-04
# Epoch 6/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 4.3583e-04
# Epoch 7/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 3.2861e-04
# Epoch 8/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 3.0162e-04
# Epoch 9/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 2.8932e-04
# Epoch 10/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 2.9383e-04
# Epoch 11/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 2.0519e-04
# Epoch 12/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 3.7494e-04
# Epoch 13/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 4.7741e-04
# Epoch 14/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 3.2987e-04
# Epoch 15/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 3.1556e-04
# Epoch 16/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 3.2223e-04
# Epoch 17/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 2.3695e-04
# Epoch 18/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 2.0000e-04
# Epoch 19/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 1.9061e-04
# Epoch 20/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 2.1324e-04
# Epoch 21/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 1.9792e-04
# Epoch 22/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 2.1607e-04
# Epoch 23/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 2.2513e-04
# Epoch 24/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 2.2716e-04
# Epoch 25/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 2.2917e-04
# Epoch 26/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 3.2750e-04
# Epoch 27/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 2.4937e-04
# Epoch 28/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 2.3045e-04
# Epoch 29/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 2.5572e-04
# 39/39 [==============================] - 0s 778us/step
# Validation MSE: 10.489123556708051, MAE: 2.161803121328162, R2: 0.996759932339388
# Iteration: 18, window_size=30, batch_size=256, epochs=30, units=12, lstm_layers=1
# Epoch 1/30
# 20/20 [==============================] - 1s 14ms/step - loss: 0.0055 - val_loss: 4.2860e-04
# Epoch 2/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 3.4691e-04
# Epoch 3/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 1.7056e-04
# Epoch 4/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 2.5412e-04
# Epoch 5/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 1.1562e-04
# Epoch 6/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 2.6129e-04
# Epoch 7/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 1.0674e-04
# Epoch 8/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 1.4294e-04
# Epoch 9/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 1.6190e-04
# Epoch 10/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 1.3577e-04
# Epoch 11/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 6.4048e-04
# Epoch 12/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 9.3176e-05
# Epoch 13/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 2.1794e-04
# Epoch 14/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 9.0351e-05
# Epoch 15/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 1.8345e-04
# Epoch 16/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 8.6871e-05
# Epoch 17/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 8.7099e-05
# Epoch 18/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 8.7999e-05
# Epoch 19/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 1.7341e-04
# Epoch 20/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 9.5017e-05
# Epoch 21/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 2.2856e-04
# Epoch 22/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 1.0620e-04
# Epoch 23/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 1.1044e-04
# Epoch 24/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 1.8123e-04
# Epoch 25/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 1.0726e-04
# Epoch 26/30
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 2.0865e-04
# 39/39 [==============================] - 0s 709us/step
# Validation MSE: 4.7805542522705595, MAE: 1.333933976053363, R2: 0.9984949930058381
# Iteration: 19, window_size=15, batch_size=1, epochs=30, units=32, lstm_layers=1
# Epoch 1/30
# 4973/4973 [==============================] - 6s 1ms/step - loss: 0.0016 - val_loss: 6.6177e-05
# Epoch 2/30
# 4973/4973 [==============================] - 5s 1ms/step - loss: 9.0978e-04 - val_loss: 8.1279e-05
# Epoch 3/30
# 4973/4973 [==============================] - 5s 1ms/step - loss: 8.4013e-04 - val_loss: 2.3166e-04
# Epoch 4/30
# 4973/4973 [==============================] - 5s 1ms/step - loss: 7.8911e-04 - val_loss: 1.7223e-04
# Epoch 5/30
# 4973/4973 [==============================] - 5s 1ms/step - loss: 7.3276e-04 - val_loss: 1.2292e-04
# Epoch 6/30
# 4973/4973 [==============================] - 5s 1ms/step - loss: 7.7494e-04 - val_loss: 9.7635e-05
# Epoch 7/30
# 4973/4973 [==============================] - 5s 1ms/step - loss: 6.4872e-04 - val_loss: 7.5514e-05
# Epoch 8/30
# 4973/4973 [==============================] - 5s 1ms/step - loss: 7.4984e-04 - val_loss: 1.2011e-04
# Epoch 9/30
# ...
# Epoch 8/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 0.0011 - val_loss: 4.3870e-04
# Epoch 9/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 0.0011 - val_loss: 1.5573e-04
# Epoch 10/30
# 4977/4977 [==============================] - 10s 2ms/step - loss: 0.0011 - val_loss: 2.2976e-04
# Epoch 11/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 12/30
# 4977/4977 [==============================] - 10s 2ms/step - loss: 9.9422e-04 - val_loss: 1.8505e-04
# Epoch 13/30
# 4977/4977 [==============================] - 10s 2ms/step - loss: 9.8064e-04 - val_loss: 1.3133e-04
# Epoch 14/30
# 4977/4977 [==============================] - 10s 2ms/step - loss: 9.5290e-04 - val_loss: 5.2660e-04
# Epoch 15/30
# 4977/4977 [==============================] - 10s 2ms/step - loss: 9.5978e-04 - val_loss: 2.4429e-04
# Epoch 16/30
# 4977/4977 [==============================] - 10s 2ms/step - loss: 9.8273e-04 - val_loss: 1.8385e-04
# Epoch 17/30
# 4977/4977 [==============================] - 10s 2ms/step - loss: 9.0044e-04 - val_loss: 4.5802e-04
# Epoch 18/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 9.2827e-04 - val_loss: 1.2483e-04
# Epoch 19/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 9.4165e-04 - val_loss: 1.8463e-04
# Epoch 20/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 9.0261e-04 - val_loss: 8.3971e-04
# Epoch 21/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 9.4203e-04 - val_loss: 1.7778e-04
# Epoch 22/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 8.3657e-04 - val_loss: 2.0663e-04
# Epoch 23/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 8.9559e-04 - val_loss: 4.0530e-04
# Epoch 24/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 8.4633e-04 - val_loss: 3.4513e-04
# Epoch 25/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 9.1769e-04 - val_loss: 7.0702e-04
# Epoch 26/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 9.1071e-04 - val_loss: 1.8638e-04
# Epoch 27/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 8.3378e-04 - val_loss: 5.5604e-04
# Epoch 28/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 8.2099e-04 - val_loss: 9.3826e-05
# Epoch 29/30
# 4977/4977 [==============================] - 11s 2ms/step - loss: 7.9362e-04 - val_loss: 9.9435e-05
# Epoch 30/30
# 4977/4977 [==============================] - 10s 2ms/step - loss: 8.9590e-04 - val_loss: 2.0713e-04
# 39/39 [==============================] - 0s 1ms/step
# Validation MSE: 11.398191657131044, MAE: 2.308427911338557, R2: 0.9962419541390592
# Iteration: 36, window_size=60, batch_size=256, epochs=30, units=16, lstm_layers=2
# Epoch 1/30
# 20/20 [==============================] - 2s 36ms/step - loss: 0.0453 - val_loss: 0.0103
# Epoch 2/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 3/30
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0032 - val_loss: 3.9305e-04
# Epoch 4/30
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0026 - val_loss: 2.5582e-04
# Epoch 5/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 2.7080e-04
# Epoch 6/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0022 - val_loss: 2.0835e-04
# Epoch 7/30
# 20/20 [==============================] - 0s 23ms/step - loss: 0.0021 - val_loss: 3.7598e-04
# Epoch 8/30
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0020 - val_loss: 1.8157e-04
# Epoch 9/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0019 - val_loss: 1.7212e-04
# Epoch 10/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 1.8363e-04
# Epoch 11/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0018 - val_loss: 2.2905e-04
# Epoch 12/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0018 - val_loss: 3.0969e-04
# Epoch 13/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0019 - val_loss: 1.8330e-04
# Epoch 14/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 1.5606e-04
# Epoch 15/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 2.4545e-04
# Epoch 16/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0019 - val_loss: 1.5891e-04
# Epoch 17/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0018 - val_loss: 1.8506e-04
# Epoch 18/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 1.6198e-04
# Epoch 19/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 1.7582e-04
# Epoch 20/30
# 20/20 [==============================] - 0s 24ms/step - loss: 0.0017 - val_loss: 1.5368e-04
# Epoch 21/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 1.5426e-04
# Epoch 22/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 1.5480e-04
# Epoch 23/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 1.5755e-04
# Epoch 24/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 2.9616e-04
# Epoch 25/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 1.8794e-04
# Epoch 26/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 2.2726e-04
# Epoch 27/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0014 - val_loss: 1.5172e-04
# Epoch 28/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 1.4579e-04
# Epoch 29/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 1.7313e-04
# Epoch 30/30
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 2.0005e-04
# 39/39 [==============================] - 0s 2ms/step
# Validation MSE: 11.008916964067838, MAE: 1.7863489246621789, R2: 0.99676496636102
# Iteration: 37, window_size=60, batch_size=1, epochs=30, units=32, lstm_layers=3
# Epoch 1/30
# 4937/4937 [==============================] - 46s 9ms/step - loss: 0.0027 - val_loss: 8.4469e-04
# Epoch 2/30
# 4937/4937 [==============================] - 44s 9ms/step - loss: 0.0018 - val_loss: 7.1580e-04
# Epoch 3/30
# 4937/4937 [==============================] - 43s 9ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 4/30
# 4937/4937 [==============================] - 43s 9ms/step - loss: 0.0015 - val_loss: 2.8072e-04
# Epoch 5/30
# 4937/4937 [==============================] - 44s 9ms/step - loss: 0.0013 - val_loss: 1.4101e-04
# Epoch 6/30
# 4937/4937 [==============================] - 42s 9ms/step - loss: 0.0013 - val_loss: 9.6239e-05
# Epoch 7/30
# 4937/4937 [==============================] - 42s 9ms/step - loss: 0.0012 - val_loss: 1.9543e-04
# Epoch 8/30
# 4937/4937 [==============================] - 43s 9ms/step - loss: 0.0011 - val_loss: 2.6152e-04
# Epoch 9/30
# 4937/4937 [==============================] - 43s 9ms/step - loss: 0.0011 - val_loss: 1.0866e-04
# Epoch 10/30
# 4937/4937 [==============================] - 45s 9ms/step - loss: 0.0010 - val_loss: 1.5880e-04
# Epoch 11/30
# 4937/4937 [==============================] - 45s 9ms/step - loss: 0.0010 - val_loss: 1.8190e-04
# Epoch 12/30
# 4937/4937 [==============================] - 44s 9ms/step - loss: 0.0011 - val_loss: 1.3961e-04
# Epoch 13/30
# 4937/4937 [==============================] - 43s 9ms/step - loss: 9.1985e-04 - val_loss: 9.9827e-05
# Epoch 14/30
# 4937/4937 [==============================] - 44s 9ms/step - loss: 9.8060e-04 - val_loss: 2.3126e-04
# Epoch 15/30
# 4937/4937 [==============================] - 44s 9ms/step - loss: 9.7254e-04 - val_loss: 3.7547e-04
# Epoch 16/30
# 4937/4937 [==============================] - 46s 9ms/step - loss: 9.1160e-04 - val_loss: 7.9965e-05
# Epoch 17/30
# 4937/4937 [==============================] - 45s 9ms/step - loss: 8.8688e-04 - val_loss: 8.9417e-04
# Epoch 18/30
# 4937/4937 [==============================] - 44s 9ms/step - loss: 9.4510e-04 - val_loss: 3.3626e-04
# Epoch 19/30
# 4937/4937 [==============================] - 44s 9ms/step - loss: 9.8396e-04 - val_loss: 3.9181e-04
# Epoch 20/30
# 4937/4937 [==============================] - 45s 9ms/step - loss: 9.2969e-04 - val_loss: 3.2456e-04
# Epoch 21/30
# 4937/4937 [==============================] - 45s 9ms/step - loss: 8.9494e-04 - val_loss: 5.5241e-04
# Epoch 22/30
# 4937/4937 [==============================] - 44s 9ms/step - loss: 8.6835e-04 - val_loss: 1.1951e-04
# Epoch 23/30
# 4937/4937 [==============================] - 46s 9ms/step - loss: 8.7660e-04 - val_loss: 1.7054e-04
# Epoch 24/30
# 4937/4937 [==============================] - 45s 9ms/step - loss: 8.6280e-04 - val_loss: 1.3398e-04
# Epoch 25/30
# 4937/4937 [==============================] - 45s 9ms/step - loss: 8.4036e-04 - val_loss: 8.6094e-05
# Epoch 26/30
#  709/4937 [===>..........................] - ETA: 36s - loss: 8.2434e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Beispielhafte Ausführung der Funktion
# ----> 2 results = random_search(n_iter=53)
#
# Cell In[5], line 70, in random_search(n_iter)
#      68 earlystop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
#      69 # Modell trainieren
# ---> 70 history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val), verbose=1, callbacks=[earlystop])
#      72 # Vorhersagen auf den Validierungsdaten
#      73 y_pred = model.predict(X_val)
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/keras/src/engine/training.py:1783, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 with tf.profiler.experimental.Trace(
#    1776     "train",
#    1777     epoch_num=epoch,
#    (...)
#    1780     _r=1,
#    1781 ):
#    1782     callbacks.on_train_batch_begin(step)
# -> 1783     tmp_logs = self.train_function(iterator)
#    1784     if data_handler.should_sync:
#    1785         context.async_wait()
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:831, in Function.__call__(self, *args, **kwds)
#     828 compiler = "xla" if self._jit_compile else "nonXla"
#     830 with OptionalXlaContext(self._jit_compile):
# --> 831   result = self._call(*args, **kwds)
#     833 new_tracing_count = self.experimental_get_tracing_count()
#     834 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:867, in Function._call(self, *args, **kwds)
#     864   self._lock.release()
#     865   # In this case we have created variables on the first call, so we run the
#     866   # defunned version which is guaranteed to never create variables.
# --> 867   return tracing_compilation.call_function(
#     868       args, kwds, self._no_variable_creation_config
#     869   )
#     870 elif self._variable_creation_config is not None:
#     871   # Release the lock early so that multiple threads can perform the call
#     872   # in parallel.
#     873   self._lock.release()
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1264, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1260 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1261 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1262     and executing_eagerly):
#    1263   # No tape is watching; skip to running the function.
# -> 1264   return self._inference_function.flat_call(args)
#    1265 forward_backward = self._select_forward_and_backward_functions(
#    1266     args,
#    1267     possible_gradient_type,
#    1268     executing_eagerly)
#    1269 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:217, in AtomicFunction.flat_call(self, args)
#     215 def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216   """Calls with tensor inputs and returns the structured output."""
# --> 217   flat_outputs = self(*args)
#     218   return self.function_type.pack_output(flat_outputs)
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:252, in AtomicFunction.__call__(self, *args)
#     250 with record.stop_recording():
#     251   if self._bound_context.executing_eagerly():
# --> 252     outputs = self._bound_context.call_function(
#     253         self.name,
#     254         list(args),
#     255         len(self.function_type.flat_outputs),
#     256     )
#     257   else:
#     258     outputs = make_call_op_in_graph(
#     259         self,
#     260         list(args),
#     261         self._bound_context.function_call_options.as_attrs(),
#     262     )
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1479, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1477 cancellation_context = cancellation.context()
#    1478 if cancellation_context is None:
# -> 1479   outputs = execute.execute(
#    1480       name.decode("utf-8"),
#    1481       num_outputs=num_outputs,
#    1482       inputs=tensor_inputs,
#    1483       attrs=attrs,
#    1484       ctx=self,
#    1485   )
#    1486 else:
#    1487   outputs = execute.execute_with_cancellation(
#    1488       name.decode("utf-8"),
#    1489       num_outputs=num_outputs,
#    (...)
#    1493       cancellation_manager=cancellation_context,
#    1494   )
#
# File ~/.local/share/virtualenvs/Jupyter-K0eqoyk3/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# KeyboardInterrupt:

# %%
def plot_predictions_from_models(X_data, y_data, data_type, model_names=None, csv_filename='./results/hyperparameter_search_results.csv', save_fig=True):
    """
    Diese Funktion plotet die Vorhersagen ausgewählter Modelle gegen den echten Kurs.
    :param X_data: Die Eingangsdaten (Features).
    :param y_data: Die echten Zielwerte (z.B. Aktienkurs).
    :param data_type: Typ der Daten ('Train', 'Test').
    :param model_names: Liste von Modellnamen oder einzelner Modellname. Wenn None, werden alle Modelle aus der CSV-Datei verwendet.
    :param csv_filename: Pfad zur CSV-Datei mit Modellinformationen.
    :param save_fig: Wenn True, wird die Figur gespeichert.
    """
    
    # Scaler laden
    scaler = joblib.load('./scaler/scaler.pkl')
    
    # CSV-Datei laden
    df = pd.read_csv(csv_filename)
    
    # Wenn keine Modellnamen übergeben werden, alle Modelle aus der CSV verwenden
    if model_names is None:
        model_names = df['Model Name'].tolist()
    elif isinstance(model_names, str):  # Falls nur ein einzelner Modellname übergeben wird
        model_names = [model_names]

    # Rückskalieren der echten Werte
    y_data_rescaled = scaler.inverse_transform(y_data.reshape(-1, 1))

    # Erstelle einen Plotly-Plot
    fig = go.Figure()

    # Füge die echten Werte hinzu
    fig.add_trace(go.Scatter(y=y_data_rescaled.flatten(), mode='lines', name=f'Echte {data_type} Werte', line=dict(color='black')))

    # Vorhersagen der ausgewählten Modelle plotten
    for model_name in model_names:
        if model_name in df['Model Name'].values:
            # Extrahiere den window_size aus dem Modellnamen (z.B. 'model_20211010-101010_ws30_bs32_...')
            window_size = int(model_name.split('_ws')[1].split('_')[0])

            # Bereite die Daten für das Modell mit der extrahierten window_size vor
            X_windowed = create_windowed_data_for_model(X_data, window_size)

            # Lade das Modell
            model = load_model(f'./models/{model_name}', compile=False)

            # Vorhersagen machen
            y_pred = model.predict(X_windowed)
            y_pred_rescaled = scaler.inverse_transform(y_pred)

            # Modellvorhersage in den Plot einfügen
            fig.add_trace(go.Scatter(y=y_pred_rescaled.flatten(), mode='lines', name=f'{model_name}', line=dict(width=1)))
        else:
            print(f"Modell {model_name} wurde in der CSV-Datei nicht gefunden.")

    # Layout des Plots
    fig.update_layout(
        title=f'Vorhersagen der Modelle auf {data_type}daten',
        xaxis_title='Zeit',
        yaxis_title='Preis',
        showlegend=True
    )

    # Plot anzeigen
    fig.show(renderer='browser')
    
    # Optionales Speichern des Plots
    if save_fig:
        fig.write_html(f"./plots/{time.strftime('%Y%m%d-%H%M%S')}.html")


def create_windowed_data_for_model(X_data, window_size):
    """
    Bereitet die Daten so vor, dass sie für Modelle mit unterschiedlicher window_size verwendet werden können.
    :param X_data: Originale Daten, die vorfenstert werden sollen.
    :param window_size: Die Fenstergröße, die für das Modell verwendet wurde.
    :return: Fensterartige Daten für das Modell.
    """
    X_windowed = []
    for i in range(window_size, len(X_data)):
        X_windowed.append(X_data[i - window_size:i])
    return np.array(X_windowed)

# %%
plot_predictions_from_models(scaled_features, scaled_target, data_type='Prediction')
# Out:
# 193/193 [==============================] - 0s 1ms/step
# 195/195 [==============================] - 1s 2ms/step
# 195/195 [==============================] - 0s 363us/step
# 195/195 [==============================] - 0s 438us/step
# 195/195 [==============================] - 1s 966us/step
# 194/194 [==============================] - 1s 4ms/step
# 194/194 [==============================] - 0s 1ms/step
# 195/195 [==============================] - 1s 856us/step
# 195/195 [==============================] - 0s 548us/step
# 194/194 [==============================] - 1s 1ms/step
# 195/195 [==============================] - 0s 407us/step
# 194/194 [==============================] - 0s 820us/step
# 195/195 [==============================] - 0s 299us/step
# 195/195 [==============================] - 0s 707us/step
# 195/195 [==============================] - 0s 298us/step
# 195/195 [==============================] - 1s 503us/step
# 193/193 [==============================] - 0s 1ms/step
# 195/195 [==============================] - 0s 439us/step
# 195/195 [==============================] - 0s 525us/step
# 195/195 [==============================] - 0s 626us/step
# 195/195 [==============================] - 0s 636us/step
# 195/195 [==============================] - 0s 368us/step
# 195/195 [==============================] - 1s 721us/step
# 195/195 [==============================] - 0s 287us/step
# 193/193 [==============================] - 1s 5ms/step
# 195/195 [==============================] - 0s 491us/step
# 195/195 [==============================] - 0s 538us/step
# 195/195 [==============================] - 0s 428us/step
# 195/195 [==============================] - 1s 2ms/step
# 195/195 [==============================] - 1s 994us/step
# 195/195 [==============================] - 1s 1ms/step
# 195/195 [==============================] - 0s 452us/step
# 195/195 [==============================] - 0s 771us/step
# 195/195 [==============================] - 1s 578us/step
# 195/195 [==============================] - 0s 402us/step
# 195/195 [==============================] - 0s 537us/step
# 195/195 [==============================] - 0s 543us/step
# 193/193 [==============================] - 1s 3ms/step
# 195/195 [==============================] - 0s 381us/step
# 195/195 [==============================] - 0s 300us/step
# 195/195 [==============================] - 0s 281us/step
# 193/193 [==============================] - 1s 2ms/step
# 194/194 [==============================] - 0s 992us/step
# 195/195 [==============================] - 1s 993us/step
# 195/195 [==============================] - 0s 634us/step
# 195/195 [==============================] - 1s 2ms/step
# 194/194 [==============================] - 0s 1ms/step
# 195/195 [==============================] - 0s 454us/step
# 193/193 [==============================] - 1s 2ms/step
# 195/195 [==============================] -